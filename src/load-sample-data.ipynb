# %% [markdown]
# ##### **Load Sample Data**

# %%
import pandas as pd
import os

df_sample = pd.read_csv(r"C:\Users\user\Downloads\foreign_spouse.csv")

folder_path = r"C:\Users\user\Downloads\etl-postgresql-projects\etl-foreign-spouse\data"

# Full file path
file_path = os.path.join(folder_path, "sample_data.csv")

# Save a random 5-row sample
df_sample.sample(5).to_csv(file_path, index=False)

print("Sample data has been saved")
# Out:
# Sample data has been saved
